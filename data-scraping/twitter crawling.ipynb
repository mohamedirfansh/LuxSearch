# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import os
from datetime import datetime, timedelta
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
# Creating list to append tweet data to
tweets = []
tickers = ['Bottega Venetta','Dior','Balenciaga','Louis Vuitton', 'Hermes', 'Rolex', 'Tiffany and Co']

a = pd.date_range(start='11/2/2022', end='3/1/2023')
for s in tickers:
    for single_date in a:
        date=single_date.date()
        for i,tweet in enumerate(sntwitter.TwitterSearchScraper(f'{s} until:{date} lang:en').get_items()):
            if i>12:
                break
            tweets.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.sourceLabel, tweet.content, tweet.lang, tweet.url])
            
    
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(tweets, columns=["User", "Date Created", "Number of Likes","Number of Retweets", "Source of Tweet", "Tweet", "Language", "URL"])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_47416\1619054034.py:12: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.sourceLabel, tweet.content, tweet.lang, tweet.url])

# %%
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(tweets, columns=["User", "Date Created", "Number of Likes", "Number of Retweets", "Source of Tweet", "Tweet", "Language", "URL"])
tweets_df
# Out:
#                 User              Date Created  Number of Likes  \
# 0       ShadowZhavia 2022-11-01 15:32:38+00:00                1
# 1      gripper_jalon 2022-11-01 03:46:31+00:00                0
# 2          romano114 2022-10-28 12:24:47+00:00                4
# 3         U10kayShop 2022-10-28 10:10:07+00:00                5
# 4           bango_og 2022-10-28 05:14:07+00:00                0
# ...              ...                       ...              ...
# 10915  metawinsbabie 2023-02-28 18:28:14+00:00                0
# 10916  metawinsbabie 2023-02-28 18:27:19+00:00                0
# 10917  metawinsbabie 2023-02-28 18:24:18+00:00                0
# 10918  metawinsbabie 2023-02-28 18:23:33+00:00                2
# 10919  metawinsbabie 2023-02-28 18:23:08+00:00                2
#
#        Number of Retweets      Source of Tweet  \
# 0                       0  Twitter for Android
# 1                       0   Twitter for iPhone
# 2                       0   Twitter for iPhone
# 3                       8   Twitter for iPhone
# 4                       0      Twitter Web App
# ...                   ...                  ...
# 10915                   2   Twitter for iPhone
# 10916                   3   Twitter for iPhone
# 10917                   3   Twitter for iPhone
# 10918                   2   Twitter for iPhone
# 10919                   2   Twitter for iPhone
#
#                                                    Tweet Language  \
# 0      @yoongisgunner So this is y bottega venetta CD...       en
# 1      I hate when I wear bottega Venetta tire boots ...       en
# 2      Me and my #husband and friend Houseparty me we...       en
# 3      Designer: Bottega Venetta\nSizes: 40-46\nColor...       en
# 4      I MIXED DA BALENCIAGA WIT DA BOTTEGA VENETTA &...       en
# ...                                                  ...      ...
# 10915  win is so intimidating yet so handsome 😭\n\n#T...       en
# 10916  I LOVE YOU @winmetawin \n\n#TiffanyxWin #Tiffa...       en
# 10917  no words can describe how mesmerizing win is 😻...       en
# 10918  SLAYYYY!!!\n\n#TiffanyxWin #TiffanyAndCo \n@wi...       en
# 10919  he looks so goooood!!\n\n#TiffanyxWin #Tiffany...       en
#
#                                                      URL
# 0      https://twitter.com/ShadowZhavia/status/158746...
# 1      https://twitter.com/gripper_jalon/status/15872...
# 2      https://twitter.com/romano114/status/158597083...
# 3      https://twitter.com/U10kayShop/status/15859369...
# 4      https://twitter.com/bango_og/status/1585862455...
# ...                                                  ...
# 10915  https://twitter.com/metawinsbabie/status/16306...
# 10916  https://twitter.com/metawinsbabie/status/16306...
# 10917  https://twitter.com/metawinsbabie/status/16306...
# 10918  https://twitter.com/metawinsbabie/status/16306...
# 10919  https://twitter.com/metawinsbabie/status/16306...
#
# [10920 rows x 8 columns]

# %%
tweets_df.to_csv('tweets.csv', index=False)
