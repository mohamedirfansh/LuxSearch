# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd
import os
from datetime import datetime, timedelta
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2' 
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# %%
# Creating list to append tweet data to
tweets = []
tickers = ['Ralph Lauren','Dior','Balenciaga','Louis Vuitton', 'Hermes', 'Rolex', 'Tiffany and Co']

a = pd.date_range(start='11/2/2022', end='3/1/2023')
for s in tickers:
    for single_date in a:
        date=single_date.date()
        for i,tweet in enumerate(sntwitter.TwitterSearchScraper(f'{s} until:{date} lang:en').get_items()):
            if i>12:
                break
            tweets.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.sourceLabel, tweet.content, tweet.lang, tweet.url])
            
    
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(tweets, columns=["User", "Date Created", "Number of Likes","Number of Retweets", "Source of Tweet", "Tweet", "Language", "URL"])
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_40040\4155038419.py:12: FutureWarning: content is deprecated, use rawContent instead
#   tweets.append([tweet.user.username, tweet.date, tweet.likeCount, tweet.retweetCount, tweet.sourceLabel, tweet.content, tweet.lang, tweet.url])

# %%
# Creating a dataframe to load the list
tweets_df = pd.DataFrame(tweets, columns=["User", "Date Created", "Number of Likes", "Number of Retweets", "Source of Tweet", "Tweet", "Language", "URL"])
tweets_df
# Out:
#                   User              Date Created  Number of Likes  \
# 0           RivalTimes 2022-11-01 23:52:17+00:00                0
# 1             adrisa24 2022-11-01 23:48:59+00:00                0
# 2       FortniteBoards 2022-11-01 23:42:09+00:00                0
# 3             GeyiPoji 2022-11-01 23:41:08+00:00                0
# 4       modcontrollerz 2022-11-01 23:39:48+00:00                0
# ...                ...                       ...              ...
# 10915  brightwintology 2023-02-28 23:22:22+00:00                3
# 10916        nebulawin 2023-02-28 23:21:07+00:00               11
# 10917   WINNIEBETADINE 2023-02-28 23:17:37+00:00                3
# 10918   WINNIEBETADINE 2023-02-28 23:15:53+00:00                0
# 10919     metawinopass 2023-02-28 23:15:48+00:00                4
#
#        Number of Retweets                  Source of Tweet  \
# 0                       0                      Jetpack.com
# 1                       0                         Poshmark
# 2                       0  FortniteBoards Social Auto Post
# 3                       0                      Jetpack.com
# 4                       0                      Jetpack.com
# ...                   ...                              ...
# 10915                   2               Twitter for iPhone
# 10916                  10               Twitter for iPhone
# 10917                   2              Twitter for Android
# 10918                   3              Twitter for Android
# 10919                   2              Twitter for Android
#
#                                                    Tweet Language  \
# 0      Why is it not enough that Ralph Lauren has wit...       en
# 1      Check out this listing I just added to my #Pos...       en
# 2      🔔 Fortnite's Polo Ralph Lauren Crossover Bring...       en
# 3      The Fortnite Crossover Ralph Lauren Polo Bring...       en
# 4      Fortnite’s Polo Ralph Lauren Crossover Brings ...       en
# ...                                                  ...      ...
# 10915  #TiffanyxWin \n#TiffanyAndCo \n#winmetawin\n\n...       en
# 10916  this is so slayage\n\n#TiffanyxWin #winmetawin...       en
# 10917  Baby Bunny ☺\n\nWin Metawin \n#TiffanyxWin \n#...       en
# 10918  He is so UNREAL 😭\n\nWin Metawin \n#TiffanyxWi...       en
# 10919  Handsome 😍\n#TiffanyHighJewelry\n#TiffanyxWin ...       en
#
#                                                      URL
# 0      https://twitter.com/RivalTimes/status/15875934...
# 1      https://twitter.com/adrisa24/status/1587592568...
# 2      https://twitter.com/FortniteBoards/status/1587...
# 3      https://twitter.com/GeyiPoji/status/1587590596...
# 4      https://twitter.com/modcontrollerz/status/1587...
# ...                                                  ...
# 10915  https://twitter.com/brightwintology/status/163...
# 10916  https://twitter.com/nebulawin/status/163070971...
# 10917  https://twitter.com/WINNIEBETADINE/status/1630...
# 10918  https://twitter.com/WINNIEBETADINE/status/1630...
# 10919  https://twitter.com/metawinopass/status/163070...
#
# [10920 rows x 8 columns]

# %%
tweets_df.to_csv('tweets.csv', index=False)
