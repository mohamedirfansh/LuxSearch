# %%
import time

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from collections import Counter
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, f1_score
from sklearn.model_selection import KFold
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df = pd.read_csv('eda_polarity.csv',index_col = False)
df=df.dropna()
df.head()
# Out:
#                                                 Data  Polarity
# 0    balenciaga and the rise of trash by umair haque         0
# 1               removed the balenciaga scandal broke         0
# 2  omega aqua terra i really wanted an explorer p...         0
# 3  they seem to have a life of their own crazy di...         0
# 4  since i dont twitter and shoe only put up a mi...         0

# %%
tt_df_eda = pd.read_csv('twitter_df_eda(with_prediction).csv', index_col=False,lineterminator='\n')
tt_df_eda = tt_df_eda.dropna()
tt_df_eda = tt_df_eda.drop(columns=['Unnamed: 0'])
tt_df_eda
# Out:
#                  User               Date Created  Number of Likes  \
# 0          RivalTimes  2022-11-01 23:52:17+00:00                0
# 1      FortniteBoards  2022-11-01 23:42:09+00:00                0
# 2            GeyiPoji  2022-11-01 23:41:08+00:00                0
# 3      modcontrollerz  2022-11-01 23:39:48+00:00                0
# 4        fuzzcassette  2022-11-01 23:39:16+00:00                6
# ...               ...                        ...              ...
# 9700  brightwintology  2023-02-28 23:22:22+00:00                3
# 9701        nebulawin  2023-02-28 23:21:07+00:00               11
# 9702   WINNIEBETADINE  2023-02-28 23:17:37+00:00                3
# 9703   WINNIEBETADINE  2023-02-28 23:15:53+00:00                0
# 9704     metawinopass  2023-02-28 23:15:48+00:00                4
#
#       Number of Retweets                  Source of Tweet  \
# 0                      0                      Jetpack.com
# 1                      0  FortniteBoards Social Auto Post
# 2                      0                      Jetpack.com
# 3                      0                      Jetpack.com
# 4                      0               Twitter for iPhone
# ...                  ...                              ...
# 9700                   2               Twitter for iPhone
# 9701                  10               Twitter for iPhone
# 9702                   2              Twitter for Android
# 9703                   3              Twitter for Android
# 9704                   2              Twitter for Android
#
#                                                   Tweet Language  \
# 0     Why is it not enough that Ralph Lauren has wit...       en
# 1      Fortnites Polo Ralph Lauren Crossover Brings ...       en
# 2     The Fortnite Crossover Ralph Lauren Polo Bring...       en
# 3     Fortnites Polo Ralph Lauren Crossover Brings R...       en
# 4                  need the fortnite ralph lauren polo        en
# ...                                                 ...      ...
# 9700  TiffanyxWin TiffanyAndCo winmetawinpleaseeeeeee         en
# 9701  this is so slayageTiffanyxWin winmetawin winme...       en
# 9702  Baby Bunny Win Metawin TiffanyxWin TiffanyAndC...       en
# 9703  He is so UNREAL Win Metawin TiffanyxWin Tiffan...       en
# 9704  Handsome TiffanyHighJewelryTiffanyxWin Tiffany...       en
#
#                                                     URL  \
# 0     https://twitter.com/RivalTimes/status/15875934...
# 1     https://twitter.com/FortniteBoards/status/1587...
# 2     https://twitter.com/GeyiPoji/status/1587590596...
# 3     https://twitter.com/modcontrollerz/status/1587...
# 4     https://twitter.com/fuzzcassette/status/158759...
# ...                                                 ...
# 9700  https://twitter.com/brightwintology/status/163...
# 9701  https://twitter.com/nebulawin/status/163070971...
# 9702  https://twitter.com/WINNIEBETADINE/status/1630...
# 9703  https://twitter.com/WINNIEBETADINE/status/1630...
# 9704  https://twitter.com/metawinopass/status/163070...
#
#                                            Cleaned Data  \
# 0     Why not enough Ralph Lauren withdrawn sacks co...
# 1     Fortnites Polo Ralph Lauren Crossover Brings R...
# 2     The Fortnite Crossover Ralph Lauren Polo Bring...
# 3     Fortnites Polo Ralph Lauren Crossover Brings R...
# 4                       need fortnite ralph lauren polo
# ...                                                 ...
# 9700    TiffanyxWin TiffanyAndCo winmetawinpleaseeeeeee
# 9701  slayageTiffanyxWin winmetawin winmetawin Tiffa...
# 9702  Baby Bunny Win Metawin TiffanyxWin TiffanyAndC...
# 9703  He UNREAL Win Metawin TiffanyxWin TiffanyAndCo...
# 9704  Handsome TiffanyHighJewelryTiffanyxWin Tiffany...
#
#                                          Tokenized Data  \
# 0     ['Why', 'is', 'it', 'not', 'enough', 'that', '...
# 1     ['Fortnites', 'Polo', 'Ralph', 'Lauren', 'Cros...
# 2     ['The', 'Fortnite', 'Crossover', 'Ralph', 'Lau...
# 3     ['Fortnites', 'Polo', 'Ralph', 'Lauren', 'Cros...
# 4     ['need', 'the', 'fortnite', 'ralph', 'lauren',...
# ...                                                 ...
# 9700  ['TiffanyxWin', 'TiffanyAndCo', 'winmetawinple...
# 9701  ['this', 'is', 'so', 'slayageTiffanyxWin', 'wi...
# 9702  ['Baby', 'Bunny', 'Win', 'Metawin', 'TiffanyxW...
# 9703  ['He', 'is', 'so', 'UNREAL', 'Win', 'Metawin',...
# 9704  ['Handsome', 'TiffanyHighJewelryTiffanyxWin', ...
#
#                                Tokenized LowerCase Data  \
# 0     ['why', 'is', 'it', 'not', 'enough', 'that', '...
# 1     ['fortnites', 'polo', 'ralph', 'lauren', 'cros...
# 2     ['the', 'fortnite', 'crossover', 'ralph', 'lau...
# 3     ['fortnites', 'polo', 'ralph', 'lauren', 'cros...
# 4     ['need', 'the', 'fortnite', 'ralph', 'lauren',...
# ...                                                 ...
# 9700  ['tiffanyxwin', 'tiffanyandco', 'winmetawinple...
# 9701  ['this', 'is', 'so', 'slayagetiffanyxwin', 'wi...
# 9702  ['baby', 'bunny', 'win', 'metawin', 'tiffanyxw...
# 9703  ['he', 'is', 'so', 'unreal', 'win', 'metawin',...
# 9704  ['handsome', 'tiffanyhighjewelrytiffanyxwin', ...
#
#                                    Tokenized Clean Data  \
# 0     ['Why', 'not', 'enough', 'Ralph', 'Lauren', 'w...
# 1     ['Fortnites', 'Polo', 'Ralph', 'Lauren', 'Cros...
# 2     ['The', 'Fortnite', 'Crossover', 'Ralph', 'Lau...
# 3     ['Fortnites', 'Polo', 'Ralph', 'Lauren', 'Cros...
# 4       ['need', 'fortnite', 'ralph', 'lauren', 'polo']
# ...                                                 ...
# 9700  ['TiffanyxWin', 'TiffanyAndCo', 'winmetawinple...
# 9701  ['slayageTiffanyxWin', 'winmetawin', 'winmetaw...
# 9702  ['Baby', 'Bunny', 'Win', 'Metawin', 'TiffanyxW...
# 9703  ['He', 'UNREAL', 'Win', 'Metawin', 'TiffanyxWi...
# 9704  ['Handsome', 'TiffanyHighJewelryTiffanyxWin', ...
#
#                          Tokenized Clean LowerCase Data  Relevance
# 0     ['why', 'not', 'enough', 'ralph', 'lauren', 'w...          1
# 1     ['fortnites', 'polo', 'ralph', 'lauren', 'cros...          1
# 2     ['the', 'fortnite', 'crossover', 'ralph', 'lau...          1
# 3     ['fortnites', 'polo', 'ralph', 'lauren', 'cros...          1
# 4       ['need', 'fortnite', 'ralph', 'lauren', 'polo']          1
# ...                                                 ...        ...
# 9700  ['tiffanyxwin', 'tiffanyandco', 'winmetawinple...          1
# 9701  ['slayagetiffanyxwin', 'winmetawin', 'winmetaw...          0
# 9702  ['baby', 'bunny', 'win', 'metawin', 'tiffanyxw...          1
# 9703  ['he', 'unreal', 'win', 'metawin', 'tiffanyxwi...          1
# 9704  ['handsome', 'tiffanyhighjewelrytiffanyxwin', ...          1
#
# [9705 rows x 14 columns]

# %% [markdown]
# ## Stacked Ensemble

# %%
# Split the Dataset into random Train and Test
X_train = df['Data']
X_test = tt_df_eda['Cleaned Data']
y_train = df['Polarity']


# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape)
# Out:
# Train Set : (15378,) (15378,)
# Test Set  : (9705,)

# %%
# Split the Dataset into random Train and Test
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 0.50, random_state = 42)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Val Set  :", X_val.shape, y_val.shape)
X_train
# Out:
# Train Set : (7689,) (7689,)
# Val Set  : (7689,) (7689,)
# 8262     check out this listing i just added to my clos...
# 6784          authentic cristobal balenciaga knitwear ebay
# 7782                             cristobal balenciaga gmgm
# 2480     i neer wanted to take the vaccine but felt obl...
# 12787    daman magazine christian dior bts twt wtffff o...
#                                ...
# 5191                        grannie louis vuitton spring x
# 13418    best of the day on the rumors are going crazy ...
# 5390     this picture was also by louis vuitton on twit...
# 860      malcolmrenoldz clownworld why do you think was...
# 7270     nan qchaul kg burberry louis vuitton dior ston...
# Name: Data, Length: 7689, dtype: object

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tf_idf = TfidfVectorizer(ngram_range = (1, 3), binary = True, smooth_idf = False)

X_train = tf_idf.fit_transform(X_train)
X_val=tf_idf.transform(X_val)
X_test = tf_idf.transform(X_test)

# %%
#importing the packages

from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC

# %%
def get_accuracy_CV(model):

    # Set KFold to shuffle data before the split
    kf = StratifiedKFold(5, shuffle = True)

    # Get Accuracy scores
    accuracy = cross_val_score(model, X_train, y_train, scoring = "accuracy", cv = kf)

    return accuracy.mean()

res = pd.Series([get_accuracy_CV(MultinomialNB(alpha = i)) for i in np.arange(1, 3, 0.1)], index = np.arange(1, 3, 0.1))

best_alpha = np.round(res.idxmax(), 2)
print('Best alpha: ', best_alpha)

plt.plot(res)
plt.title('Accuracy vs. Alpha')
plt.xlabel('Alpha')
plt.ylabel('Accuracy')
plt.show()
# Out:
# Best alpha:  1.0

# %%
#specifying the initial learners
model1 = MultinomialNB(alpha = 1.0)
model2 = LogisticRegression(random_state=42,max_iter=1000)
model3 = SVC(kernel = 'rbf', random_state = 42)

# %%
#training the initial learners
model1.fit(X_train,y_train)
model2.fit(X_train,y_train)
model3.fit(X_train,y_train)
# Out:
# SVC(random_state=42)

# %%
#making predictions for the validation data
preds1 = model1.predict(X_val)
preds2 = model2.predict(X_val)
preds3 = model3.predict(X_val)

#making predictions for the test data
test_preds1 = model1.predict(X_test)
test_preds2 = model2.predict(X_test)
test_preds3 = model3.predict(X_test)

# %%
#making a new dataset for training our final model by stacking the predictions on the validation data
train_stack = np.column_stack((preds1,preds2,preds3))

#making the final test set for our final model by stacking the predictions on the test data
test_stack = np.column_stack((test_preds1,test_preds2,test_preds3))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
final_model = RandomForestClassifier()

#training the final model on the stacked predictions
final_model.fit(train_stack,y_val)
# Out:
# RandomForestClassifier()

# %%
st=time.time()
final_predictions = final_model.predict(test_stack)
et=time.time()
elapsed_time=et-st
print("Time taken for prediction: ", elapsed_time,"s")
# Out:
# Time taken for prediction:  0.07917952537536621 s

# %%
tt_df_eda['Polarity'] = final_predictions

# %%
tt_df_eda.head()
# Out:
#              User               Date Created  Number of Likes  \
# 0      RivalTimes  2022-11-01 23:52:17+00:00                0
# 1  FortniteBoards  2022-11-01 23:42:09+00:00                0
# 2        GeyiPoji  2022-11-01 23:41:08+00:00                0
# 3  modcontrollerz  2022-11-01 23:39:48+00:00                0
# 4    fuzzcassette  2022-11-01 23:39:16+00:00                6
#
#    Number of Retweets                  Source of Tweet  \
# 0                   0                      Jetpack.com
# 1                   0  FortniteBoards Social Auto Post
# 2                   0                      Jetpack.com
# 3                   0                      Jetpack.com
# 4                   0               Twitter for iPhone
#
#                                                Tweet Language  \
# 0  Why is it not enough that Ralph Lauren has wit...       en
# 1   Fortnites Polo Ralph Lauren Crossover Brings ...       en
# 2  The Fortnite Crossover Ralph Lauren Polo Bring...       en
# 3  Fortnites Polo Ralph Lauren Crossover Brings R...       en
# 4               need the fortnite ralph lauren polo        en
#
#                                                  URL  \
# 0  https://twitter.com/RivalTimes/status/15875934...
# 1  https://twitter.com/FortniteBoards/status/1587...
# 2  https://twitter.com/GeyiPoji/status/1587590596...
# 3  https://twitter.com/modcontrollerz/status/1587...
# 4  https://twitter.com/fuzzcassette/status/158759...
#
#                                         Cleaned Data  \
# 0  Why not enough Ralph Lauren withdrawn sacks co...
# 1  Fortnites Polo Ralph Lauren Crossover Brings R...
# 2  The Fortnite Crossover Ralph Lauren Polo Bring...
# 3  Fortnites Polo Ralph Lauren Crossover Brings R...
# 4                    need fortnite ralph lauren polo
#
#                                       Tokenized Data  \
# 0  ['Why', 'is', 'it', 'not', 'enough', 'that', '...
# 1  ['Fortnites', 'Polo', 'Ralph', 'Lauren', 'Cros...
# 2  ['The', 'Fortnite', 'Crossover', 'Ralph', 'Lau...
# 3  ['Fortnites', 'Polo', 'Ralph', 'Lauren', 'Cros...
# 4  ['need', 'the', 'fortnite', 'ralph', 'lauren',...
#
#                             Tokenized LowerCase Data  \
# 0  ['why', 'is', 'it', 'not', 'enough', 'that', '...
# 1  ['fortnites', 'polo', 'ralph', 'lauren', 'cros...
# 2  ['the', 'fortnite', 'crossover', 'ralph', 'lau...
# 3  ['fortnites', 'polo', 'ralph', 'lauren', 'cros...
# 4  ['need', 'the', 'fortnite', 'ralph', 'lauren',...
#
#                                 Tokenized Clean Data  \
# 0  ['Why', 'not', 'enough', 'Ralph', 'Lauren', 'w...
# 1  ['Fortnites', 'Polo', 'Ralph', 'Lauren', 'Cros...
# 2  ['The', 'Fortnite', 'Crossover', 'Ralph', 'Lau...
# 3  ['Fortnites', 'Polo', 'Ralph', 'Lauren', 'Cros...
# 4    ['need', 'fortnite', 'ralph', 'lauren', 'polo']
#
#                       Tokenized Clean LowerCase Data  Relevance  Polarity
# 0  ['why', 'not', 'enough', 'ralph', 'lauren', 'w...          1         2
# 1  ['fortnites', 'polo', 'ralph', 'lauren', 'cros...          1         2
# 2  ['the', 'fortnite', 'crossover', 'ralph', 'lau...          1         4
# 3  ['fortnites', 'polo', 'ralph', 'lauren', 'cros...          1         2
# 4    ['need', 'fortnite', 'ralph', 'lauren', 'polo']          1         4

# %%
tt_df_eda.to_csv("Polarity_twitter_stacked2.csv", encoding="utf-8", index=False)
